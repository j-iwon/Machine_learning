# %%
# 호박씨
# https://www.kaggle.com/datasets/muratkokludataset/pumpkin-seeds-dataset

# %%
# 타겟 분포 샘플링시 더 효과가 좋지 않음. 값이 차이가 얼마 나지 않으므로 그대로 진행
# 이상치 제거
# 민맥스 스케일러 진행
# 상관관계 분석 후 컬럼 제거
# 차원 축소 진행

# %% [markdown]
# ### **호박씨 품질 데이터**
# > **Area** 면적
# > **Perimeter** 둘레
# > **Major_Axis_Length** 가장 긴 지름
# > **Minor_Axis_Length** 가장 짧은 지름
# > **Convex_Area**  외곽을 감싸는 볼록 다각형의 면적
# > **Equiv_Diameter** 호박씨의 면적과 동일한 면적을 가진 원의 지름
# > **Eccentricity** 호박씨의 타원 형태 정도 (0에 가까울 수록 원형, 1에 가까울수록 길쭉한 타원형)
# > **Solidity** 호박씨의 볼록 다각형 면적과 호박씨의 실제 면적간의 비율
# > **Extent** 호박씨의 면적과 외곽을 감싸는 최소한의 사각형의 면적 간의 비율
# > **Roundness** 호박씨의 원형에 가까운 정도 (값이 높을수록 원형에 가까움)
# > **Aspect_Ration** 호박씨의 장축과 단축의 비율 (1에 가까울 수록 원형)
# > **Compactness** 호박씨의 경계 길이와 면적의 비율
# > **Class** 호박씨의 종류

# %%
import pandas as pd

p_df = pd.read_csv('./datasets/Pumpkin_Seeds_Dataset.csv')
p_df
# Out:
#        Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0     56276    888.242           326.1485           220.2388        56831
# 1     76631   1068.146           417.1932           234.2289        77280
# 2     71623   1082.987           435.8328           211.0457        72663
# 3     66458    992.051           381.5638           222.5322        67118
# 4     66107    998.146           383.8883           220.4545        67117
# ...     ...        ...                ...                ...          ...
# 2495  79637   1224.710           533.1513           190.4367        80381
# 2496  69647   1084.318           462.9416           191.8210        70216
# 2497  87994   1210.314           507.2200           222.1872        88702
# 2498  80011   1182.947           501.9065           204.7531        80902
# 2499  84934   1159.933           462.8951           234.5597        85781
#
#       Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  \
# ...

# %% [markdown]
# #### **데이터 확인**

# %%
p_df.isna().sum()
# Out:
# Area                 0
# Perimeter            0
# Major_Axis_Length    0
# Minor_Axis_Length    0
# Convex_Area          0
# Equiv_Diameter       0
# Eccentricity         0
# Solidity             0
# Extent               0
# Roundness            0
# Aspect_Ration        0
# Compactness          0
# Class                0
# dtype: int64

# %%
p_df.duplicated().sum()
# Out:
# 0

# %%
p_df['Class'].value_counts()
# Out:
# Class
# Çerçevelik       1300
# Ürgüp Sivrisi    1200
# Name: count, dtype: int64

# %% [markdown]
# #### **데이터 전처리**

# %%
pre_p_df = p_df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

class_encoder = LabelEncoder()
classes = class_encoder.fit_transform(pre_p_df['Class'].tolist())
pre_p_df['Class'] = classes
pre_p_df
# Out:
#        Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0     56276    888.242           326.1485           220.2388        56831
# 1     76631   1068.146           417.1932           234.2289        77280
# 2     71623   1082.987           435.8328           211.0457        72663
# 3     66458    992.051           381.5638           222.5322        67118
# 4     66107    998.146           383.8883           220.4545        67117
# ...     ...        ...                ...                ...          ...
# 2495  79637   1224.710           533.1513           190.4367        80381
# 2496  69647   1084.318           462.9416           191.8210        70216
# 2497  87994   1210.314           507.2200           222.1872        88702
# 2498  80011   1182.947           501.9065           204.7531        80902
# 2499  84934   1159.933           462.8951           234.5597        85781
#
#       Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  \
# ...

# %%
pre_p_df = pre_p_df.drop(labels=['Area'], axis=1).reset_index(drop=True)
pre_p_df
# Out:
#       Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0       888.242           326.1485           220.2388        56831
# 1      1068.146           417.1932           234.2289        77280
# 2      1082.987           435.8328           211.0457        72663
# 3       992.051           381.5638           222.5322        67118
# 4       998.146           383.8883           220.4545        67117
# ...         ...                ...                ...          ...
# 2495   1224.710           533.1513           190.4367        80381
# 2496   1084.318           462.9416           191.8210        70216
# 2497   1210.314           507.2200           222.1872        88702
# 2498   1182.947           501.9065           204.7531        80902
# 2499   1159.933           462.8951           234.5597        85781
#
#       Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  \
# 0           267.6805        0.7376    0.9902  0.7453     0.8963
# ...

# %%
# 히스토그램 그려보기
pre_p_df.hist(figsize=(10, 10))
# Out:
# array([[<Axes: title={'center': 'Perimeter'}>,
#         <Axes: title={'center': 'Major_Axis_Length'}>,
#         <Axes: title={'center': 'Minor_Axis_Length'}>],
#        [<Axes: title={'center': 'Convex_Area'}>,
#         <Axes: title={'center': 'Equiv_Diameter'}>,
#         <Axes: title={'center': 'Eccentricity'}>],
#        [<Axes: title={'center': 'Solidity'}>,
#         <Axes: title={'center': 'Extent'}>,
#         <Axes: title={'center': 'Roundness'}>],
#        [<Axes: title={'center': 'Aspect_Ration'}>,
#         <Axes: title={'center': 'Compactness'}>,
#         <Axes: title={'center': 'Class'}>]], dtype=object)

# %%
import numpy as np
from sklearn.metrics import mean_squared_log_error, mean_squared_error, r2_score

def get_evaluation(y_test, prediction):
    MSE = mean_squared_error(y_test, prediction)
    RMSE = np.sqrt(MSE)
    # MSLE = mean_squared_log_error(y_test, prediction)
    # RMSLE = np.sqrt(mean_squared_log_error(y_test, prediction))
    R2 = r2_score(y_test, prediction)
    # print('MSE: {:.4f}, RMSE: {:.4f}, MSLE: {:.4f}, RMSLE: {:.4f}, R2: {:.4f}'\
          # .format(MSE, RMSE, MSLE, RMSLE, R2))
    print('MSE: {:.4f}, RMSE: {:.4f}, R2: {:.4f}'\
          .format(MSE, RMSE, R2))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

features, targets = pre_p_df.iloc[:, :-1], pre_p_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train.values, y_train.values)
# Out:
# LinearRegression()

# %%
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# MSE: 0.0912, RMSE: 0.3020, R2: 0.6309
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.preprocessing import PolynomialFeatures

features, targets = pre_p_df.iloc[:, :-1], pre_p_df.iloc[:, -1]

poly_features = PolynomialFeatures(degree=2).fit_transform(features)

X_train, X_test, y_train, y_test = \
train_test_split(poly_features, targets, test_size=0.2, random_state=0)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# MSE: 0.1008, RMSE: 0.3175, R2: 0.5965

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split

features, targets = pre_p_df.iloc[:, :-1], pre_p_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=1000)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]
for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 0.1440, RMSE: 0.3795, R2: 0.4172
# RandomForestRegressor
# MSE: 0.0678, RMSE: 0.2605, R2: 0.7254
# GradientBoostingRegressor
# MSE: 0.0706, RMSE: 0.2658, R2: 0.7142
# XGBRegressor
# MSE: 0.0808, RMSE: 0.2842, R2: 0.6731
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000141 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2676
# [LightGBM] [Info] Number of data points in the train set: 2000, number of used features: 11
# [LightGBM] [Info] Start training from score 0.488500
# LGBMRegressor
# MSE: 0.0727, RMSE: 0.2696, R2: 0.7058

# %% [markdown]
# #### **1Cycle 결과**
# > PolynomialFeatures보다 LinearRegression의 결과가 좋으며, 트리를 사용한 결과 **RandomForest** 모델이 가장 적합하다.
# > target을 언더샘플링하여 분포를 조정해본다.

# %%
pre_p1_df=pre_p_df.copy()

# %%
pre_p1_df['Class'].value_counts()
# Out:
# Class
# 0    1300
# 1    1200
# Name: count, dtype: int64

# %%
# 타겟 데이터 비중 동일하게 조정
zero = pre_p1_df[pre_p1_df.Class == 0].sample(1200, random_state=124)
one = pre_p1_df[pre_p1_df.Class == 1]

pre_p1_df = pd.concat([zero, one])
pre_p1_df.reset_index(drop=True, inplace=True)

# %%
pre_p1_df['Class'].value_counts()
# Out:
# Class
# 0    1200
# 1    1200
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

features, targets = pre_p1_df.iloc[:, :-1], pre_p1_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train.values, y_train.values)
# Out:
# LinearRegression()

# %%
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# MSE: 0.1035, RMSE: 0.3217, R2: 0.5851
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split

features, targets = pre_p1_df.iloc[:, :-1], pre_p1_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=1000)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]
for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 0.1979, RMSE: 0.4449, R2: 0.2063
# RandomForestRegressor
# MSE: 0.0909, RMSE: 0.3016, R2: 0.6353
# GradientBoostingRegressor
# MSE: 0.0901, RMSE: 0.3002, R2: 0.6386
# XGBRegressor
# MSE: 0.0994, RMSE: 0.3153, R2: 0.6013
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2673
# [LightGBM] [Info] Number of data points in the train set: 1920, number of used features: 11
# [LightGBM] [Info] Start training from score 0.506250
# LGBMRegressor
# MSE: 0.0874, RMSE: 0.2957, R2: 0.6494

# %% [markdown]
# #### **2Cycle 결과**
# > 언더샘플링 결과 R2가 하락하였다.
# > 오버샘플링을 진행해본다.

# %%
pre_p2_df = pre_p_df.copy()

# %%
pre_p2_df
# Out:
#       Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0       888.242           326.1485           220.2388        56831
# 1      1068.146           417.1932           234.2289        77280
# 2      1082.987           435.8328           211.0457        72663
# 3       992.051           381.5638           222.5322        67118
# 4       998.146           383.8883           220.4545        67117
# ...         ...                ...                ...          ...
# 2495   1224.710           533.1513           190.4367        80381
# 2496   1084.318           462.9416           191.8210        70216
# 2497   1210.314           507.2200           222.1872        88702
# 2498   1182.947           501.9065           204.7531        80902
# 2499   1159.933           462.8951           234.5597        85781
#
#       Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  \
# 0           267.6805        0.7376    0.9902  0.7453     0.8963
# ...

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# 데이터 세트 분리
# 피처, 타겟 데이터 분리
features, targets = pre_p2_df.iloc[:, :-1], pre_p2_df.iloc[:, -1]

# 문제/정답 및 학습/테스트 데이터 분리
X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# SMOTE (over sampling)
# smote 객체 생성
smote = SMOTE(random_state=124)
# over sampling 진행
over_X_train, over_y_train = smote.fit_resample(X_train, y_train)

l_r = LinearRegression()
l_r.fit(over_X_train.values, over_y_train.values)
# Out:
# LinearRegression()

# %%
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# MSE: 0.0929, RMSE: 0.3048, R2: 0.6277
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split

# 데이터 세트 분리
# 피처, 타겟 데이터 분리
features, targets = pre_p2_df.iloc[:, :-1], pre_p2_df.iloc[:, -1]

# 문제/정답 및 학습/테스트 데이터 분리
X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# SMOTE (over sampling)
# smote 객체 생성
smote = SMOTE(random_state=124)
# over sampling 진행
over_X_train, over_y_train = smote.fit_resample(X_train, y_train)

dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=1000)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]
for model in models:
    model.fit(over_X_train, over_y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 0.1580, RMSE: 0.3975, R2: 0.3670
# RandomForestRegressor
# MSE: 0.0790, RMSE: 0.2811, R2: 0.6833
# GradientBoostingRegressor
# MSE: 0.0770, RMSE: 0.2774, R2: 0.6916
# XGBRegressor
# MSE: 0.0921, RMSE: 0.3035, R2: 0.6310
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2684
# [LightGBM] [Info] Number of data points in the train set: 2080, number of used features: 11
# [LightGBM] [Info] Start training from score 0.500000
# LGBMRegressor
# MSE: 0.0863, RMSE: 0.2937, R2: 0.6544

# %% [markdown]
# #### **3Cycle 결과**
# > 언더샘플링 했을때보다는 결과가 좋지만, 타겟의 값을 조정하지 않았을 때 제일 결과가 좋다.
# > 전체 데이터를 MinMaxScaler 해본다.

# %%
pre_p3_df = pre_p_df.copy()

# %%
pre_p3_df
# Out:
#       Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0       888.242           326.1485           220.2388        56831
# 1      1068.146           417.1932           234.2289        77280
# 2      1082.987           435.8328           211.0457        72663
# 3       992.051           381.5638           222.5322        67118
# 4       998.146           383.8883           220.4545        67117
# ...         ...                ...                ...          ...
# 2495   1224.710           533.1513           190.4367        80381
# 2496   1084.318           462.9416           191.8210        70216
# 2497   1210.314           507.2200           222.1872        88702
# 2498   1182.947           501.9065           204.7531        80902
# 2499   1159.933           462.8951           234.5597        85781
#
#       Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  \
# 0           267.6805        0.7376    0.9902  0.7453     0.8963
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# 정규화 객체 생성
min = MinMaxScaler()

# 수치형 데이터 추출
columns = ['Perimeter', 'Major_Axis_Length', 'Minor_Axis_Length', 'Convex_Area', 'Equiv_Diameter', 'Eccentricity', 'Solidity', 'Extent', 'Roundness',
          'Aspect_Ration', 'Compactness', 'Class']

# 정규화 변환
pre_p3_df[columns] = min.fit_transform(pre_p3_df[columns])

pre_p3_df
# Out:
#       Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0      0.028593           0.015551           0.443011     0.094037
# 1      0.288960           0.282492           0.534065     0.321202
# 2      0.310438           0.337143           0.383178     0.269913
# 3      0.178831           0.178027           0.457938     0.208314
# 4      0.187652           0.184843           0.444415     0.208303
# ...         ...                ...                ...          ...
# 2495   0.515547           0.622479           0.249046     0.355651
# 2496   0.312365           0.416625           0.258055     0.242729
# 2497   0.494712           0.546449           0.455692     0.448088
# 2498   0.455106           0.530869           0.342223     0.361439
# 2499   0.421798           0.416489           0.536218     0.415639
#
#       Equiv_Diameter  Eccentricity  Solidity    Extent  Roundness  \
# 0           0.121346      0.538377  0.944591  0.766869   0.887532
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

features, targets = pre_p3_df.iloc[:, :-1], pre_p3_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# MSE: 0.0912, RMSE: 0.3020, R2: 0.6309

# %%
from sklearn.preprocessing import PolynomialFeatures

features, targets = pre_p3_df.iloc[:, :-1], pre_p3_df.iloc[:, -1]

poly_features = PolynomialFeatures(degree=2).fit_transform(features)

X_train, X_test, y_train, y_test = \
train_test_split(poly_features, targets, test_size=0.2, random_state=0)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# MSE: 0.1003, RMSE: 0.3167, R2: 0.5987

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split

features, targets = pre_p3_df.iloc[:, :-1], pre_p3_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=1000)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]
for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 0.1440, RMSE: 0.3795, R2: 0.4172
# RandomForestRegressor
# MSE: 0.0680, RMSE: 0.2607, R2: 0.7249
# GradientBoostingRegressor
# MSE: 0.0706, RMSE: 0.2657, R2: 0.7142
# XGBRegressor
# MSE: 0.0808, RMSE: 0.2842, R2: 0.6731
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000126 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2676
# [LightGBM] [Info] Number of data points in the train set: 2000, number of used features: 11
# [LightGBM] [Info] Start training from score 0.488500
# LGBMRegressor
# MSE: 0.0726, RMSE: 0.2695, R2: 0.7060

# %% [markdown]
# > MinMaxScaler 처리 후 Linear 와 트리 모델의 성능이 향상되었다
# > 차원축소 해본다

# %%
from sklearn.decomposition import PCA

# 차원축소
pca = PCA(n_components=2)
features, targets = pre_p3_df.iloc[:, :-1], pre_p3_df.iloc[:, -1]

pca_features = pca.fit_transform(features)
print(pca_features.shape)
print(pca.explained_variance_ratio_)
print(pca.explained_variance_ratio_.sum())
# Out:
# (2500, 2)
# [0.53166194 0.34278937]
# 0.8744513173970052

# %%
pca_columns = [f'pca{i+1}' for i in range(pca_features.shape[1])]
pca_df = pd.DataFrame(pca_features, columns=pca_columns)
pca_df.loc[:, 'target'] = pre_p_df['Class']
pca_df
# Out:
#           pca1      pca2  target
# 0    -0.885982  0.055697       0
# 1    -0.283263 -0.095403       0
# 2    -0.087918  0.168411       0
# 3    -0.492290  0.038898       0
# 4    -0.430898  0.102161       0
# ...        ...       ...     ...
# 2495  0.646521  0.492698       1
# 2496  0.154364  0.440913       1
# 2497  0.276421 -0.026785       1
# 2498  0.311271  0.208311       1
# 2499  0.015297 -0.123932       1
#
# [2500 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x="pca1", y="pca2", hue='target', data=pca_df, alpha=0.5)
plt.show()

# %%
from sklearn.decomposition import PCA

# 14번 반복
for i in range(11):
    # 1차원~14차원까지 객체 생성
    pca = PCA(n_components=(i + 1))

    # 학습 데이터로 병합
    pca_train = pca.fit_transform(over_X_train)

    # 보존률 확인
    print(pca.explained_variance_ratio_.sum())
# Out:
# 0.5350663094958631
# 0.8712939990817258
# 0.9759796733576364
# 0.9920880969178523
# 0.9963776227582575
# 0.9990895593604185
# 0.9996490090970638
# 0.9998686330237101
# 0.9999718225446825
# 0.9999900620418828
# 0.9999999999999999

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA

features, targets = pre_p3_df.iloc[:, :-1], pre_p3_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()

pipe = Pipeline([('std', StandardScaler()), ('pca', PCA(n_components=6)), ('l_r', l_r)])
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('std', StandardScaler()), ('pca', PCA(n_components=6)),
#                 ('l_r', LinearRegression())])

# %%
prediction = pipe.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# MSE: 0.1044, RMSE: 0.3231, R2: 0.5776

# %%
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

features, targets = pre_p3_df.iloc[:, :-1], pre_p3_df.iloc[:, -1]
X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor(random_state=124)
lgb_r = LGBMRegressor(random_state=124)

models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]
for model in models:
    pipe = Pipeline([('std', StandardScaler()), ('pca', PCA(n_components=6)), (f'{model}', model)])
    pipe.fit(X_train, y_train)
    prediction = pipe.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 0.1540, RMSE: 0.3924, R2: 0.3767
# RandomForestRegressor
# MSE: 0.0758, RMSE: 0.2753, R2: 0.6933
# GradientBoostingRegressor
# MSE: 0.0727, RMSE: 0.2696, R2: 0.7059
# XGBRegressor
# MSE: 0.0921, RMSE: 0.3035, R2: 0.6271
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 2000, number of used features: 6
# [LightGBM] [Info] Start training from score 0.488500
# LGBMRegressor
# MSE: 0.0799, RMSE: 0.2828, R2: 0.6764

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

for i in range(1):
    lda = LinearDiscriminantAnalysis(n_components=(i + 1))
    
    lda_train = lda.fit_transform(over_X_train, over_y_train)

    print(lda.explained_variance_ratio_.sum())
# Out:
# 1.0

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=1)

lda_train = lda.fit_transform(over_X_train, over_y_train)

lda_columns = [f'lda{i + 1}' for i in range(lda_train.shape[1])]
lda_train_df = pd.DataFrame(lda_train, columns=lda_columns)
lda_train_df.loc[:, 'target'] = over_y_train

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA

features, targets = pre_p3_df.iloc[:, :-1], pre_p3_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()

pipe = Pipeline([('std', StandardScaler()), ('lda', LinearDiscriminantAnalysis(n_components=1)), ('l_r', l_r)])
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('std', StandardScaler()),
#                 ('lda', LinearDiscriminantAnalysis(n_components=1)),
#                 ('l_r', LinearRegression())])

# %%
prediction = pipe.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# MSE: 0.0912, RMSE: 0.3020, R2: 0.6309

# %%
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

features, targets = pre_p3_df.iloc[:, :-1], pre_p3_df.iloc[:, -1]
X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor(random_state=124)
lgb_r = LGBMRegressor(random_state=124)

models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]
for model in models:
    pipe = Pipeline([('std', StandardScaler()), ('lda', LinearDiscriminantAnalysis(n_components=1)), (f'{model}', model)])
    pipe.fit(X_train, y_train)
    prediction = pipe.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 0.1760, RMSE: 0.4195, R2: 0.2877
# RandomForestRegressor
# MSE: 0.1188, RMSE: 0.3446, R2: 0.5193
# GradientBoostingRegressor
# MSE: 0.0780, RMSE: 0.2793, R2: 0.6844
# XGBRegressor
# MSE: 0.0879, RMSE: 0.2965, R2: 0.6443
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000036 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 2000, number of used features: 1
# [LightGBM] [Info] Start training from score 0.488500
# LGBMRegressor
# MSE: 0.0827, RMSE: 0.2876, R2: 0.6652

# %% [markdown]
# > 차원축소한게 더 안 좋음

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# 데이터 세트 분리
# 피처, 타겟 데이터 분리
features, targets = pre_p3_df.iloc[:, :-1], pre_p3_df.iloc[:, -1]
# 파라미터 값 조정
parameters = {'max_depth': [5, 10, 20], 'min_samples_split': [10, 50, 100]}

# 분류 모델 객체 생성
rfc = RandomForestClassifier()

# 파라미터 값 설정
g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=5, return_train_score=True, scoring='accuracy')

# 훈련
g_rfc.fit(features, targets)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [5, 10, 20],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='accuracy')

# %%
# 훈련 결과 확인
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                         params  mean_test_score  \
# 0    {'max_depth': 5, 'min_samples_split': 10}           0.8844
# 1    {'max_depth': 5, 'min_samples_split': 50}           0.8812
# 2   {'max_depth': 5, 'min_samples_split': 100}           0.8832
# 3   {'max_depth': 10, 'min_samples_split': 10}           0.8880
# 4   {'max_depth': 10, 'min_samples_split': 50}           0.8844
# 5  {'max_depth': 10, 'min_samples_split': 100}           0.8820
# 6   {'max_depth': 20, 'min_samples_split': 10}           0.8900
# 7   {'max_depth': 20, 'min_samples_split': 50}           0.8848
# 8  {'max_depth': 20, 'min_samples_split': 100}           0.8816
#
#    rank_test_score
# 0                4
# 1                9
# 2                6
# 3                2
# 4                4
# 5                7
# 6                1
# 7                3
# 8                8

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
# 테스트 데이터 세트 분리
X_test, y_test = pre_p3_df.iloc[:, :-1], pre_p3_df.iloc[:, -1]

# 최적의 모델 담기
rfc = g_rfc.best_estimator_

# 예측
prediction = rfc.predict(X_test)
# 평가 (오차행렬)
get_evaluation(y_test, prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[1257   43]
#  [  75 1125]]
# 정확도: 0.9528, 정밀도: 0.9632, 재현율: 0.9375, F1: 0.9502, ROC-AUC: 0.9522
# ################################################################################
