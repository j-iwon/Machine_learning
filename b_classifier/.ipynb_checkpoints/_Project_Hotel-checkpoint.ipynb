# %% [markdown]
# ## **🏨호텔 예약 취소 예측**

# %% [markdown]
# **Feature**
#
# > **Booking_ID**: 예약 ID
# > **number of adults**: 성인 수
# > **number of children**: 자녀의 수
# > **number of weekend nights**: 주말 밤 수
# > **number of week nights**: 주중 밤 수
# > **type of meal**: 식사의 종류
# > **car parking space**: 주차 공간
# > **room type**: 객실 유형
# > **lead time**: 예약일과 도착일 사이의 일수
# > **market segment type**: 온라인/오프라인 예약 유형
# > **repeated**: 고객이 이전에 호텔에 방문한 적이 있는지 여부
# > **P-C**: 예약이 취소될 확률
# > **P-not-C**: 예약이 취소되지 않을 확률
# > **average price**: 평균 가격
# > **special requests**: 고객이 요청한 특별 서비스의 수
# > **date of reservation**: 예약 날짜
#
#
# **Target**
#
# > **booking status**: 예약 상태

# %%
import pandas as pd

hotel_df = pd.read_csv('./datasets/booking.csv')
hotel_df
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# 3                             0                      2   Meal Plan 1
# 4                             1                      2  Not Selected
# ...                         ...                    ...           ...
# 36280                         0                      2   Meal Plan 2
# 36281                         1                      3   Meal Plan 1
# 36282                         1                      3   Meal Plan 1
# 36283                         0                      4   Meal Plan 1
# 36284                         0                      5   Meal Plan 1
#
#        car parking space    room type  lead time market segment type  \
# 0                      0  Room_Type 1        224             Offline
# 1                      0  Room_Type 1          5              Online
# 2                      0  Room_Type 1          1              Online
# 3                      0  Room_Type 1        211              Online
# 4                      0  Room_Type 1         48              Online
# ...                  ...          ...        ...                 ...
# 36280                  0  Room_Type 1        346              Online
# 36281                  0  Room_Type 1         34              Online
# 36282                  0  Room_Type 4         83              Online
# 36283                  0  Room_Type 1        121             Offline
# 36284                  0  Room_Type 4         44              Online
#
#        repeated  P-C  P-not-C  average price  special requests  \
# 0             0    0        0          88.00                 0
# 1             0    0        0         106.68                 1
# 2             0    0        0          50.00                 0
# 3             0    0        0         100.00                 1
# 4             0    0        0          77.00                 0
# ...         ...  ...      ...            ...               ...
# 36280         0    0        0         115.00                 1
# 36281         0    0        0         107.55                 1
# 36282         0    0        0         105.61                 1
# 36283         0    0        0          96.90                 1
# 36284         0    0        0         133.44                 3
#
#       date of reservation booking status
# 0               10/2/2015   Not_Canceled
# 1               11/6/2018   Not_Canceled
# 2               2/28/2018       Canceled
# 3               5/20/2017       Canceled
# 4               4/11/2018       Canceled
# ...                   ...            ...
# 36280           9/13/2018       Canceled
# 36281          10/15/2017   Not_Canceled
# 36282          12/26/2018   Not_Canceled
# 36283            7/6/2018   Not_Canceled
# 36284          10/18/2018   Not_Canceled
#
# [36285 rows x 17 columns]

# %%
print(hotel_df.columns)
# Out:
# Index(['Booking_ID', 'number of adults', 'number of children',
#        'number of weekend nights', 'number of week nights', 'type of meal',
#        'car parking space', 'room type', 'lead time', 'market segment type',
#        'repeated', 'P-C', 'P-not-C', 'average price', 'special requests',
#        'date of reservation', 'booking status'],
#       dtype='object')

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                36285 non-null  object
#  1   number of adults          36285 non-null  int64
#  2   number of children        36285 non-null  int64
#  3   number of weekend nights  36285 non-null  int64
#  4   number of week nights     36285 non-null  int64
#  5   type of meal              36285 non-null  object
#  6   car parking space         36285 non-null  int64
#  7   room type                 36285 non-null  object
#  8   lead time                 36285 non-null  int64
#  9   market segment type       36285 non-null  object
#  10  repeated                  36285 non-null  int64
#  11  P-C                       36285 non-null  int64
#  12  P-not-C                   36285 non-null  int64
#  13  average price             36285 non-null  float64
#  14  special requests          36285 non-null  int64
#  15  date of reservation       36285 non-null  object
#  16  booking status            36285 non-null  object
# dtypes: float64(1), int64(10), object(6)
# memory usage: 4.7+ MB

# %%
# 결측치 검사
hotel_df.isna().sum()
# Out:
# Booking_ID                  0
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# type of meal                0
# car parking space           0
# room type                   0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# date of reservation         0
# booking status              0
# dtype: int64

# %%
# 이상치 제거

# %%
# 데이터 복사
h_df = hotel_df.copy()

# %%
h_df['booking status'].value_counts()
# Out:
# booking status
# Not_Canceled    24396
# Canceled        11889
# Name: count, dtype: int64

# %%
# 불필요한 컬럼 제거
h_df.drop(labels=['Booking_ID',
                  'P-C',
                  'P-not-C',
                  'date of reservation'
                  ], axis=1, inplace=True)
display(h_df)
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36280                 2                   0                         0
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36283                 3                   0                         0
# 36284                 2                   0                         0
#
#        number of week nights  type of meal  car parking space    room type  \
# 0                          5   Meal Plan 1                  0  Room_Type 1
# 1                          3  Not Selected                  0  Room_Type 1
# 2                          3   Meal Plan 1                  0  Room_Type 1
# 3                          2   Meal Plan 1                  0  Room_Type 1
# 4                          2  Not Selected                  0  Room_Type 1
# ...                      ...           ...                ...          ...
# 36280                      2   Meal Plan 2                  0  Room_Type 1
# 36281                      3   Meal Plan 1                  0  Room_Type 1
# 36282                      3   Meal Plan 1                  0  Room_Type 4
# 36283                      4   Meal Plan 1                  0  Room_Type 1
# 36284                      5   Meal Plan 1                  0  Room_Type 4
#
#        lead time market segment type  repeated  average price  \
# 0            224             Offline         0          88.00
# 1              5              Online         0         106.68
# 2              1              Online         0          50.00
# 3            211              Online         0         100.00
# 4             48              Online         0          77.00
# ...          ...                 ...       ...            ...
# 36280        346              Online         0         115.00
# 36281         34              Online         0         107.55
# 36282         83              Online         0         105.61
# 36283        121             Offline         0          96.90
# 36284         44              Online         0         133.44
#
#        special requests booking status
# 0                     0   Not_Canceled
# 1                     1   Not_Canceled
# 2                     0       Canceled
# 3                     1       Canceled
# 4                     0       Canceled
# ...                 ...            ...
# 36280                 1       Canceled
# 36281                 1   Not_Canceled
# 36282                 1   Not_Canceled
# 36283                 1   Not_Canceled
# 36284                 3   Not_Canceled
#
# [36285 rows x 13 columns]

# %%
h_df['type of meal'].value_counts()
# Out:
# type of meal
# Meal Plan 1     27842
# Not Selected     5132
# Meal Plan 2      3306
# Meal Plan 3         5
# Name: count, dtype: int64

# %%
# "type of meal" 컬럼에서 "Meal Plan 1", "Meal Plan 2", "Meal Plan 3"을 "Selected"로 변환
h_df['type of meal'] = h_df['type of meal'].replace(['Meal Plan 1', 'Meal Plan 2', 'Meal Plan 3'], 'Selected')

# %%
h_df['type of meal'].value_counts()
# Out:
# type of meal
# Selected        31153
# Not Selected     5132
# Name: count, dtype: int64

# %%
h_df['room type'].value_counts()
# Out:
# room type
# Room_Type 1    28138
# Room_Type 4     6059
# Room_Type 6      966
# Room_Type 2      692
# Room_Type 5      265
# Room_Type 7      158
# Room_Type 3        7
# Name: count, dtype: int64

# %%
h_df['room type'] = h_df['room type'].apply(lambda x: x[10])

# %%
h_df['room type'].value_counts()
# Out:
# room type
# 1    28138
# 4     6059
# 6      966
# 2      692
# 5      265
# 7      158
# 3        7
# Name: count, dtype: int64

# %%
# 문자열 데이터 변환
from sklearn.preprocessing import LabelEncoder

meal_encoder = LabelEncoder()
meals = meal_encoder.fit_transform(h_df['type of meal'].tolist())
h_df['type of meal'] = meals

market_encoder = LabelEncoder()
markets = market_encoder.fit_transform(h_df['market segment type'].tolist())
h_df['market segment type'] = markets

booking_encoder = LabelEncoder()
bookings = booking_encoder.fit_transform(h_df['booking status'].tolist())
h_df['booking status'] = bookings

h_df
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36280                 2                   0                         0
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36283                 3                   0                         0
# 36284                 2                   0                         0
#
#        number of week nights  type of meal  car parking space room type  \
# 0                          5             1                  0         1
# 1                          3             0                  0         1
# 2                          3             1                  0         1
# 3                          2             1                  0         1
# 4                          2             0                  0         1
# ...                      ...           ...                ...       ...
# 36280                      2             1                  0         1
# 36281                      3             1                  0         1
# 36282                      3             1                  0         4
# 36283                      4             1                  0         1
# 36284                      5             1                  0         4
#
#        lead time  market segment type  repeated  average price  \
# 0            224                    3         0          88.00
# 1              5                    4         0         106.68
# 2              1                    4         0          50.00
# 3            211                    4         0         100.00
# 4             48                    4         0          77.00
# ...          ...                  ...       ...            ...
# 36280        346                    4         0         115.00
# 36281         34                    4         0         107.55
# 36282         83                    4         0         105.61
# 36283        121                    3         0          96.90
# 36284         44                    4         0         133.44
#
#        special requests  booking status
# 0                     0               1
# 1                     1               1
# 2                     0               0
# 3                     1               0
# 4                     0               0
# ...                 ...             ...
# 36280                 1               0
# 36281                 1               1
# 36282                 1               1
# 36283                 1               1
# 36284                 3               1
#
# [36285 rows x 13 columns]

# %%
h_df.hist(figsize=(10, 10))
# Out:
# array([[<Axes: title={'center': 'number of adults'}>,
#         <Axes: title={'center': 'number of children'}>,
#         <Axes: title={'center': 'number of weekend nights'}>],
#        [<Axes: title={'center': 'number of week nights'}>,
#         <Axes: title={'center': 'type of meal'}>,
#         <Axes: title={'center': 'car parking space'}>],
#        [<Axes: title={'center': 'lead time'}>,
#         <Axes: title={'center': 'market segment type'}>,
#         <Axes: title={'center': 'repeated'}>],
#        [<Axes: title={'center': 'average price'}>,
#         <Axes: title={'center': 'special requests'}>,
#         <Axes: title={'center': 'booking status'}>]], dtype=object)

# %%
print(h_df.columns)
print(h_df.dtypes)
# Out:
# Index(['number of adults', 'number of children', 'number of weekend nights',
#        'number of week nights', 'type of meal', 'car parking space',
#        'room type', 'lead time', 'market segment type', 'repeated',
#        'average price', 'special requests', 'booking status'],
#       dtype='object')
# number of adults              int64
# number of children            int64
# number of weekend nights      int64
# number of week nights         int64
# type of meal                  int64
# car parking space             int64
# room type                    object
# lead time                     int64
# market segment type           int64
# repeated                      int64
# average price               float64
# special requests              int64
# booking status                int64
# dtype: object

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

features = ['number of adults', 'number of children', 'number of weekend nights',
       'number of week nights', 'type of meal', 'car parking space',
       'room type', 'lead time', 'market segment type', 'repeated',
       'average price', 'special requests', 'booking status']

total_count = h_df.shape[0]
for feature in features:
    std_df = std.fit_transform(h_df[[feature]])
    count = ((std_df < -1.96) | (std_df > 1.96)).sum()
    print(f'{feature}: {count}건, {np.round(count / total_count * 100, 4)}%')
# Out:
# number of adults: 2473건, 6.8155%
# number of children: 2702건, 7.4466%
# number of weekend nights: 337건, 0.9288%
# number of week nights: 2129건, 5.8674%
# type of meal: 5132건, 14.1436%
# car parking space: 1124건, 3.0977%
# room type: 1389건, 3.828%
# lead time: 2500건, 6.8899%
# market segment type: 2533건, 6.9808%
# repeated: 930건, 2.563%
# average price: 1999건, 5.5092%
# special requests: 762건, 2.1%
# booking status: 0건, 0.0%

# %%
# 이상치 제거
sbp_df = h_df.loc[:, 'number of adults'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['number of adults']])
sbp_df['number of adults'] = std_sbp_df
sbp_df = sbp_df[sbp_df['number of adults'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'number of children'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['number of children']])
sbp_df['number of children'] = std_sbp_df
sbp_df = sbp_df[sbp_df['number of children'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'number of weekend nights'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['number of weekend nights']])
sbp_df['number of weekend nights'] = std_sbp_df
sbp_df = sbp_df[sbp_df['number of weekend nights'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'number of week nights'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['number of week nights']])
sbp_df['number of week nights'] = std_sbp_df
sbp_df = sbp_df[sbp_df['number of week nights'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'type of meal'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['type of meal']])
sbp_df['type of meal'] = std_sbp_df
sbp_df = sbp_df[sbp_df['type of meal'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'car parking space'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['car parking space']])
sbp_df['car parking space'] = std_sbp_df
sbp_df = sbp_df[sbp_df['car parking space'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'room type'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['room type']])
sbp_df['room type'] = std_sbp_df
sbp_df = sbp_df[sbp_df['room type'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'lead time'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['lead time']])
sbp_df['lead time'] = std_sbp_df
sbp_df = sbp_df[sbp_df['lead time'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'market segment type'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['market segment type']])
sbp_df['market segment type'] = std_sbp_df
sbp_df = sbp_df[sbp_df['market segment type'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'repeated'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['repeated']])
sbp_df['repeated'] = std_sbp_df
sbp_df = sbp_df[sbp_df['repeated'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'average price'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['average price']])
sbp_df['average price'] = std_sbp_df
sbp_df = sbp_df[sbp_df['average price'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

sbp_df = h_df.loc[:, 'special requests'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['special requests']])
sbp_df['special requests'] = std_sbp_df
sbp_df = sbp_df[sbp_df['special requests'].between(-1.96, 1.96)]
h_df = h_df.iloc[sbp_df.index].reset_index(drop=True)

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15636 entries, 0 to 15635
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   number of adults          15636 non-null  int64
#  1   number of children        15636 non-null  int64
#  2   number of weekend nights  15636 non-null  int64
#  3   number of week nights     15636 non-null  int64
#  4   type of meal              15636 non-null  int64
#  5   car parking space         15636 non-null  int64
#  6   room type                 15636 non-null  object
#  7   lead time                 15636 non-null  int64
#  8   market segment type       15636 non-null  int64
#  9   repeated                  15636 non-null  int64
#  10  average price             15636 non-null  float64
#  11  special requests          15636 non-null  int64
#  12  booking status            15636 non-null  int64
# dtypes: float64(1), int64(11), object(1)
# memory usage: 1.6+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = h_df.corr()
fig = plt.figure(figsize=(7, 5))
heatmap = sns.heatmap(corr, cmap="Oranges")
heatmap.set_title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')
