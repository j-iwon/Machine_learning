# %% [markdown]
# #### 1. 데이터 세트 수집
# > https://www.kaggle.com/datasets/sooyoungher/smoking-drinking-dataset
# ### 흡연과 음주에 따른 신체신호
# #### 대한민국 국민건강보험공단에서 수집한 데이터
# - 흡연과 음주가 건강에 미치는 영향력

# %% [markdown]
# #### 2. 데이터 탐색

# %%
import pandas as pd

sd_df_origin = pd.read_csv('./datasets/smoking_driking_dataset_Ver01.csv')
sd_df = sd_df_origin.copy()
sd_df
# Out:
#            sex  age  height  weight  waistline  sight_left  sight_right  \
# 0         Male   35     170      75       90.0         1.0          1.0
# 1         Male   30     180      80       89.0         0.9          1.2
# 2         Male   40     165      75       91.0         1.2          1.5
# 3         Male   50     175      80       91.0         1.5          1.2
# 4         Male   50     165      60       80.0         1.0          1.2
# ...        ...  ...     ...     ...        ...         ...          ...
# 991341    Male   45     175      80       92.1         1.5          1.5
# 991342    Male   35     170      75       86.0         1.0          1.5
# 991343  Female   40     155      50       68.0         1.0          0.7
# 991344    Male   25     175      60       72.0         1.5          1.0
# 991345    Male   50     160      70       90.5         1.0          1.5
#
#         hear_left  hear_right    SBP  ...  LDL_chole  triglyceride  \
# ...

# %% [markdown]
# ### Features
# 1 Sex - 성별
# 2 age - 나이
# 3 height - 키
# 4 weight - 몸무게
# 5 waistline - 허리둘레
# 6 sight_left - 시력(좌) 1(normal), 2(abnormal)
# 7 sight_right - 시력(우) 1(normal), 2(abnormal)
# 8 hear_left - 청력(좌)
# 9 hear_right - 청력(우)
# 10 SBP - 수축기 혈압
# 11 DBP - 이완기 혈압
# 12 BLDS - 공복혈당
# 13 tot_chole - 총 콜레스테롤
# 14 HDL_chole - HDL 콜레스테롤
# 15 LDL_chole - LDL 콜레스테롤
# 16 triglyceride - 중성지방
# 17 hemoglobin - 헤모글로빈
# 18 urine_protein - 요단백 또는 단백뇨
# 19 serum_creatinine - 혈청 크레아티닌
# 20 SGOT_AST - 혈청지오티 AST
# 21 SGOT_ALT - 혈청지오티 ALT
# 22 gamma_GTP - 감마지티피
# 23 SMK_stat_type_cd - 흡연상태 (1 = 비흡연자, 2 = 금연, 3 = 흡연)
# 24 DRK_YN - 음주여부

# %%
sd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991346 entries, 0 to 991345
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   sex               991346 non-null  object
#  1   age               991346 non-null  int64
#  2   height            991346 non-null  int64
#  3   weight            991346 non-null  int64
#  4   waistline         991346 non-null  float64
#  5   sight_left        991346 non-null  float64
#  6   sight_right       991346 non-null  float64
#  7   hear_left         991346 non-null  float64
#  8   hear_right        991346 non-null  float64
#  9   SBP               991346 non-null  float64
#  10  DBP               991346 non-null  float64
#  11  BLDS              991346 non-null  float64
#  12  tot_chole         991346 non-null  float64
#  13  HDL_chole         991346 non-null  float64
#  14  LDL_chole         991346 non-null  float64
# ...

# %%
# target 비율 확인
sd_df_origin['DRK_YN'].value_counts()
# Out:
# DRK_YN
# N    495858
# Y    495488
# Name: count, dtype: int64

# %% [markdown]
# #### 3. 데이터 전처리

# %%
# feature명 변경
sd_df.rename(columns={'DRK_YN': 'drinking'}, inplace=True)
sd_df
# Out:
#            sex  age  height  weight  waistline  sight_left  sight_right  \
# 0         Male   35     170      75       90.0         1.0          1.0
# 1         Male   30     180      80       89.0         0.9          1.2
# 2         Male   40     165      75       91.0         1.2          1.5
# 3         Male   50     175      80       91.0         1.5          1.2
# 4         Male   50     165      60       80.0         1.0          1.2
# ...        ...  ...     ...     ...        ...         ...          ...
# 991341    Male   45     175      80       92.1         1.5          1.5
# 991342    Male   35     170      75       86.0         1.0          1.5
# 991343  Female   40     155      50       68.0         1.0          0.7
# 991344    Male   25     175      60       72.0         1.5          1.0
# 991345    Male   50     160      70       90.5         1.0          1.5
#
#         hear_left  hear_right    SBP  ...  LDL_chole  triglyceride  \
# ...

# %%
# 사용하지 않을 feature 제거
sd_df = sd_df.drop(['sight_left', 'sight_right', 'hear_left', 'hear_right', 'SMK_stat_type_cd', 'HDL_chole', 'LDL_chole'], axis=1)

# %%
sd_df
# Out:
#            sex  age  height  weight  waistline    SBP   DBP   BLDS  tot_chole  \
# 0         Male   35     170      75       90.0  120.0  80.0   99.0      193.0
# 1         Male   30     180      80       89.0  130.0  82.0  106.0      228.0
# 2         Male   40     165      75       91.0  120.0  70.0   98.0      136.0
# 3         Male   50     175      80       91.0  145.0  87.0   95.0      201.0
# 4         Male   50     165      60       80.0  138.0  82.0  101.0      199.0
# ...        ...  ...     ...     ...        ...    ...   ...    ...        ...
# 991341    Male   45     175      80       92.1  114.0  80.0   88.0      198.0
# 991342    Male   35     170      75       86.0  119.0  83.0   83.0      133.0
# 991343  Female   40     155      50       68.0  110.0  70.0   90.0      205.0
# 991344    Male   25     175      60       72.0  119.0  74.0   69.0      122.0
# 991345    Male   50     160      70       90.5  133.0  79.0   99.0      225.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# 이상치 확인용 시각화
fig, axes = plt.subplots(8, 2, figsize=(30, 30))

sns.histplot(ax=axes[0, 0], data=sd_df['age'], binwidth=2, multiple='dodge')
axes[0, 0].set_xticks(range(20, sd_df['age'].max()+1, 5))

sns.histplot(ax=axes[0, 1], data=sd_df['height'], binwidth=2, multiple='dodge')

sns.histplot(ax=axes[1, 0], data=sd_df['weight'], binwidth=2, multiple='dodge')
sns.histplot(ax=axes[1, 1], data=sd_df['waistline'], binwidth=2, multiple='dodge')

sns.histplot(ax=axes[2, 0], data=sd_df['SBP'], binwidth=2, multiple='dodge')
sns.histplot(ax=axes[2, 1], data=sd_df['DBP'], binwidth=2, multiple='dodge')

sns.histplot(ax=axes[3, 0], data=sd_df['BLDS'], binwidth=2, multiple='dodge')
sns.histplot(ax=axes[3, 1], data=sd_df['tot_chole'], binwidth=2, multiple='dodge')

sns.histplot(ax=axes[4, 0], data=sd_df['triglyceride'], binwidth=2, multiple='dodge')
sns.histplot(ax=axes[4, 1], data=sd_df['hemoglobin'], binwidth=2, multiple='dodge')

sns.histplot(ax=axes[5, 0], data=sd_df['urine_protein'], binwidth=2, multiple='dodge')
sns.histplot(ax=axes[5, 1], data=sd_df['serum_creatinine'], binwidth=2, multiple='dodge')

sns.histplot(ax=axes[6, 0], data=sd_df['SGOT_AST'], binwidth=2, multiple='dodge')
sns.histplot(ax=axes[6, 1], data=sd_df['SGOT_ALT'], binwidth=2, multiple='dodge')

sns.histplot(ax=axes[7, 0], data=sd_df['gamma_GTP'], binwidth=2, multiple='dodge')

plt.show()

# %% [markdown]
# - 전체적인 이상치가 말도 안되게 높은 수치들이 있어서 그래프로 확인이 어렵다 판단하여 수치로 확인

# %%
# StandardScaler로 변환한 값 중 -1.96 ~ 1.96을 벗어난 범위의 값 확인
import numpy as np
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

features = ['SBP', 'DBP', 'BLDS', 'tot_chole', 'triglyceride', 'hemoglobin', 'urine_protein', 'serum_creatinine', 'SGOT_AST', 'SGOT_ALT', 'gamma_GTP']

total_count = sd_df.shape[0]
for feature in features:
    std_df = std.fit_transform(sd_df[[feature]])
    count = ((std_df < -1.96) | (std_df > 1.96)).sum()
    print(f'{feature}: {count}건, {np.round(count / total_count * 100, 4)}%')
# Out:
# SBP: 45971건, 4.6372%
# DBP: 44342건, 4.4729%
# BLDS: 35759건, 3.6071%
# tot_chole: 44349건, 4.4736%
# triglyceride: 35215건, 3.5522%
# hemoglobin: 40905건, 4.1262%
# urine_protein: 56171건, 5.6661%
# serum_creatinine: 2422건, 0.2443%
# SGOT_AST: 12808건, 1.292%
# SGOT_ALT: 24144건, 2.4355%
# gamma_GTP: 30344건, 3.0609%

# %% [markdown]
# - 이상치의 양이 별로 많지 않아서 이상치 전체 제거

# %%
# 이상치 제거
sbp_df = sd_df.loc[:, 'SBP'].reset_index()
std_sbp_df = std.fit_transform(sbp_df[['SBP']])
sbp_df['SBP'] = std_sbp_df
sbp_df = sbp_df[sbp_df['SBP'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[sbp_df.index].reset_index(drop=True)

dbp_df = sd_df.loc[:, 'DBP'].reset_index()
std_dbp_df = std.fit_transform(dbp_df[['DBP']])
dbp_df['DBP'] = std_dbp_df
dbp_df = dbp_df[dbp_df['DBP'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[dbp_df.index].reset_index(drop=True)

blds_df = sd_df.loc[:, 'BLDS'].reset_index()
std_blds_df = std.fit_transform(blds_df[['BLDS']])
blds_df['BLDS'] = std_blds_df
blds_df = blds_df[blds_df['BLDS'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[blds_df.index].reset_index(drop=True)

chole_df = sd_df.loc[:, 'tot_chole'].reset_index()
std_chole_df = std.fit_transform(chole_df[['tot_chole']])
chole_df['tot_chole'] = std_chole_df
chole_df = chole_df[chole_df['tot_chole'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[chole_df.index].reset_index(drop=True)

triglyceride_df = sd_df.loc[:, 'triglyceride'].reset_index()
std_triglyceride_df = std.fit_transform(triglyceride_df[['triglyceride']])
triglyceride_df['triglyceride'] = std_triglyceride_df
triglyceride_df = triglyceride_df[triglyceride_df['triglyceride'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[triglyceride_df.index].reset_index(drop=True)

hemoglobin_df = sd_df.loc[:, 'hemoglobin'].reset_index()
std_hemoglobin_df = std.fit_transform(hemoglobin_df[['hemoglobin']])
hemoglobin_df['hemoglobin'] = std_hemoglobin_df
hemoglobin_df = hemoglobin_df[hemoglobin_df['hemoglobin'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[hemoglobin_df.index].reset_index(drop=True)

up_df = sd_df.loc[:, 'urine_protein'].reset_index()
std_up_df = std.fit_transform(up_df[['urine_protein']])
up_df['urine_protein'] = std_up_df
up_df = up_df[up_df['urine_protein'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[up_df.index].reset_index(drop=True)

sc_df = sd_df.loc[:, 'serum_creatinine'].reset_index()
std_sc_df = std.fit_transform(sc_df[['serum_creatinine']])
sc_df['serum_creatinine'] = std_sc_df
sc_df = sc_df[sc_df['serum_creatinine'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[sc_df.index].reset_index(drop=True)

ast_df = sd_df.loc[:, 'SGOT_AST'].reset_index()
std_ast_df = std.fit_transform(ast_df[['SGOT_AST']])
ast_df['SGOT_AST'] = std_ast_df
ast_df = ast_df[ast_df['SGOT_AST'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[ast_df.index].reset_index(drop=True)

alt_df = sd_df.loc[:, 'SGOT_ALT'].reset_index()
std_alt_df = std.fit_transform(alt_df[['SGOT_ALT']])
alt_df['SGOT_ALT'] = std_alt_df
alt_df = alt_df[alt_df['SGOT_ALT'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[alt_df.index].reset_index(drop=True)

gtp_df = sd_df.loc[:, 'gamma_GTP'].reset_index()
std_gtp_df = std.fit_transform(gtp_df[['gamma_GTP']])
gtp_df['gamma_GTP'] = std_gtp_df
gtp_df = gtp_df[gtp_df['gamma_GTP'].between(-1.96, 1.96)]
sd_df = sd_df.iloc[gtp_df.index].reset_index(drop=True)

# %%
# 이상치 제거 후 데이터 프레임 확인
sd_df
# Out:
#            sex  age  height  weight  waistline    SBP   DBP   BLDS  tot_chole  \
# 0         Male   35     170      75       90.0  120.0  80.0   99.0      193.0
# 1         Male   30     180      80       89.0  130.0  82.0  106.0      228.0
# 2         Male   40     165      75       91.0  120.0  70.0   98.0      136.0
# 3         Male   50     165      60       80.0  138.0  82.0  101.0      199.0
# 4       Female   45     150      55       69.0  101.0  58.0   89.0      196.0
# ...        ...  ...     ...     ...        ...    ...   ...    ...        ...
# 666672    Male   45     175      80       92.1  114.0  80.0   88.0      198.0
# 666673    Male   35     170      75       86.0  119.0  83.0   83.0      133.0
# 666674  Female   40     155      50       68.0  110.0  70.0   90.0      205.0
# 666675    Male   25     175      60       72.0  119.0  74.0   69.0      122.0
# 666676    Male   50     160      70       90.5  133.0  79.0   99.0      225.0
#
# ...

# %%
# 성별과 음주여부 인코딩
from sklearn.preprocessing import LabelEncoder

drink_encoder = LabelEncoder()
targets = drink_encoder.fit_transform(sd_df['drinking'].tolist())
sd_df['drinking'] = targets

sex_encoder = LabelEncoder()
genders = sex_encoder.fit_transform(sd_df['sex'].tolist())
sd_df['sex'] = genders

# %%
# 인코딩 확인
sd_df
# Out:
#         sex  age  height  weight  waistline    SBP   DBP   BLDS  tot_chole  \
# 0         1   35     170      75       90.0  120.0  80.0   99.0      193.0
# 1         1   30     180      80       89.0  130.0  82.0  106.0      228.0
# 2         1   40     165      75       91.0  120.0  70.0   98.0      136.0
# 3         1   50     165      60       80.0  138.0  82.0  101.0      199.0
# 4         0   45     150      55       69.0  101.0  58.0   89.0      196.0
# ...     ...  ...     ...     ...        ...    ...   ...    ...        ...
# 666672    1   45     175      80       92.1  114.0  80.0   88.0      198.0
# 666673    1   35     170      75       86.0  119.0  83.0   83.0      133.0
# 666674    0   40     155      50       68.0  110.0  70.0   90.0      205.0
# 666675    1   25     175      60       72.0  119.0  74.0   69.0      122.0
# 666676    1   50     160      70       90.5  133.0  79.0   99.0      225.0
#
# ...

# %% [markdown]
# #### 4. 데이터 분리

# %%
# 데이터 분리
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.tree import DecisionTreeClassifier

features, targets = sd_df.iloc[:, :-1], sd_df.iloc[:, -1]

# stratify: 데이터 분리 시 타겟 데이터의 분포 비율에 맞춰서 나눠준다.
X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, stratify=targets, random_state=124)

dtc = DecisionTreeClassifier()
# max_depth: graphviz 에서 확인한 깊이, min_samples_split: 노드 분할 시 필요한 최소한의 샘플 수
parameters = {'max_depth': [5, 6, 7, 8], 'min_samples_split': [7, 8, 9, 10, 11]}

# %% [markdown]
# #### 5. 교차 검증

# %%
g_dtc = GridSearchCV(dtc, param_grid=parameters, cv=10, refit=True, return_train_score=True, n_jobs=-1)

# 교차 검증 진행
g_dtc.fit(X_train, y_train)

pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score', 
           'split0_test_score', 'split1_test_score', 'split2_test_score']]
# Out:
#                                        params  mean_test_score  \
# 0    {'max_depth': 5, 'min_samples_split': 7}         0.700985
# 1    {'max_depth': 5, 'min_samples_split': 8}         0.700985
# 2    {'max_depth': 5, 'min_samples_split': 9}         0.700985
# 3   {'max_depth': 5, 'min_samples_split': 10}         0.700985
# 4   {'max_depth': 5, 'min_samples_split': 11}         0.700985
# 5    {'max_depth': 6, 'min_samples_split': 7}         0.703518
# 6    {'max_depth': 6, 'min_samples_split': 8}         0.703518
# 7    {'max_depth': 6, 'min_samples_split': 9}         0.703518
# 8   {'max_depth': 6, 'min_samples_split': 10}         0.703518
# 9   {'max_depth': 6, 'min_samples_split': 11}         0.703518
# 10   {'max_depth': 7, 'min_samples_split': 7}         0.705579
# 11   {'max_depth': 7, 'min_samples_split': 8}         0.705579
# 12   {'max_depth': 7, 'min_samples_split': 9}         0.705579
# 13  {'max_depth': 7, 'min_samples_split': 10}         0.705579
# ...

# %%
dtc = g_dtc.best_estimator_

# %% [markdown]
# #### 6. graphviz

# %%
from sklearn.tree import export_graphviz

# 파일 내보내기
export_graphviz(
    dtc, 
    out_file='./images/sd_dtc01.dot', 
    class_names=drink_encoder.classes_, 
    feature_names=features.columns, 
    impurity=True, 
    filled=True
)

# %%
import graphviz

# 위에서 내보낸 파일을 읽어서 변환
with open('./images/sd_dtc01.dot') as f:
    sd_dtc01 = f.read()

sd_dtc01_graph = graphviz.Source(sd_dtc01)

# %%
# 변환한 파일의 형식 변경
sd_dtc01_graph.render(filename='sd_dtc01', directory='./images', format='png')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.645642 to fit
# 'images\\sd_dtc01.png'

# %% [markdown]
# #### graphviz 파일 이미지
# <img src="./images/sd_dtc01.png">
# - 보시다시피 쉽지않은 이미지

# %%
# 정확도 확인
from sklearn.metrics import accuracy_score

prediction = dtc.predict(X_test)

print(f'정확도: {np.round(accuracy_score(y_test, prediction) * 100, 4)}%')
# Out:
# 정확도: 70.7048%

# %% [markdown]
# #### 8. 오차행렬

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

# 타겟 데이터와 예측 객체를 전달받는다.
def get_evaluation(y_test, prediction, visualize=False):
#     오차 행렬
    confusion = confusion_matrix(y_test, prediction)
#     정확도
    accuracy = accuracy_score(y_test , prediction)
#     정밀도
    precision = precision_score(y_test , prediction)
#     재현율
    recall = recall_score(y_test , prediction)
#     F1 score
    f1 = f1_score(y_test, prediction)
#     ROC-AUC
    roc_auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    print("#" * 80)
    
    if visualize:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_predictions(y_test, prediction, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
get_evaluation(y_test, prediction)
# Out:
# 오차 행렬
# [[47492 21580]
#  [17481 46783]]
# 정확도: 0.7070, 정밀도: 0.6843, 재현율: 0.7280, F1: 0.7055, ROC-AUC: 0.7078
# ################################################################################

# %% [markdown]
# #### 9. proba

# %%
proba = dtc.predict_proba(X_test)
prediction = dtc.predict(X_test)

for proba, predict in zip(proba.tolist(), prediction.tolist()):
    print(proba, predict)
# Out:
# [0.613150947924166, 0.3868490520758339] 0
# [0.650447497794025, 0.34955250220597506] 0
# [0.907345013477089, 0.09265498652291106] 0
# [0.5254674403610574, 0.47453255963894264] 0
# [0.2534509202453988, 0.7465490797546013] 1
# [0.5298013245033113, 0.47019867549668876] 0
# [0.8194861528194861, 0.18051384718051386] 0
# [0.31971153846153844, 0.6802884615384616] 1
# [0.7775567051333068, 0.2224432948666932] 0
# [0.6296181310152127, 0.3703818689847873] 0
# [0.12065000766518473, 0.8793499923348153] 1
# [0.2061470141404698, 0.7938529858595302] 1
# [0.3298777246145667, 0.6701222753854332] 1
# [0.5397549843862599, 0.4602450156137401] 0
# [0.35987103174603174, 0.6401289682539683] 1
# [0.86125746399719, 0.13874253600280997] 0
# [0.2534509202453988, 0.7465490797546013] 1
# [0.9146282973621103, 0.0853717026378897] 0
# [0.4975255691191026, 0.5024744308808974] 1
# [0.6401137980085349, 0.35988620199146515] 0
# [0.2534509202453988, 0.7465490797546013] 1
# [0.8341658341658341, 0.16583416583416583] 0
# ...

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def precision_recall_curve_plot(y_test , proba_class1):

    precisions, recalls, thresholds = precision_recall_curve(y_test, proba_class1)
    
    # X축: threshold
    # Y축: 정밀도, 재현율 
    # 정밀도는 점선으로 표시
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
    # X축(threshold)의 Scale을 0 ~ 1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend()
    plt.grid()
    plt.show()
    
precision_recall_curve_plot(y_test, dtc.predict_proba(X_test)[:, 1].reshape(-1, 1))

# %% [markdown]
# - 0.88 ~ 0.98 사이 구간에 정답이 몰려있어서 확떨어지는 모습

# %%
from sklearn.metrics import roc_curve

def roc_curve_plot(y_test , proba_class1):
#     임계값에 따른 FPR, TPR 값
    fprs, tprs, thresholds = roc_curve(y_test, proba_class1)

#     ROC Curve를 plot 곡선으로 그림. 
    plt.plot(fprs , tprs, label='ROC')
#     가운데 대각선 직선을 그림. 
#     TPR과 FPR이 동일한 비율로 떨어진다는 것은 모델이 양성과 음성을 구별하지 못한다는 것을 의미한다.
#     다른 분류기를 판단하기 위한 기준선으로 사용되며, 
#     대각선에 가까울 수록 예측에 사용하기 힘든 모델이라는 뜻이다.
    plt.plot([0, 1], [0, 1], 'k--', label='Standard')
    
    # X축(FPR)의 Scale을 0.1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    plt.xlim(0,1); plt.ylim(0,1)
    plt.xlabel('FPR( 1 - Sensitivity )'); plt.ylabel('TPR( Recall )')
    plt.legend()
    plt.show()
    
roc_curve_plot(y_test, dtc.predict_proba(X_test)[:, 1].reshape(-1, 1))

# %% [markdown]
# #### 10. 정밀도, 재현율 수립

# %% [markdown]
# #### 흡연 여부 예측
# > True Positive (TP): 모델이 음주자를 음주자로 올바르게 분류한 경우
# > False Positive (FP): 모델이 음주자를 비음주자로 잘못 분류한 경우
# > True Negative (TN): 모델이 비음주자를 비음주자로 올바르게 분류한 경우
# > False Negative (FN): 모델이 비음주자를 음주자로 잘못 분류한 경우
#
# - 임계치를 높여 정밀도를 올려주는 것이 적합하다.
# - 음주자를 비음주자로 판단하여 오진 시 문제가 생기지만, 비음주자에게 술 조심하라고 하는건 별로 상관 없을 것 같기 때문.

# %% [markdown]
# #### 11. cuv > thresholds

# %%
# 정밀도를 높이기에는 어느정도가 괜찮을지 확인만 해보았음
from sklearn.preprocessing import Binarizer

threshold = 0.6

proba = dtc.predict_proba(X_test)
prediction = dtc.predict(X_test)

# %%
custom_proba = proba[:, 1].reshape(-1, 1)
binarizer = Binarizer(threshold=threshold).fit(custom_proba)
custom_prediction = binarizer.transform(custom_proba)

get_evaluation(y_test, custom_prediction)
# Out:
# 오차 행렬
# [[56424 12648]
#  [28247 36017]]
# 정확도: 0.6933, 정밀도: 0.7401, 재현율: 0.5605, F1: 0.6379, ROC-AUC: 0.6887
# ################################################################################

# %%
thresholds = [0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.5, 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59]

def get_evaluation_by_thresholds(y_test, proba_class1, thresholds):
    for threshold in thresholds:
        print(threshold)
        binarizer = Binarizer(threshold=threshold).fit(proba_class1)
        custom_prediction = binarizer.transform(proba_class1)
        get_evaluation(y_test, custom_prediction)

get_evaluation_by_thresholds(y_test, proba[:, 1].reshape(-1, 1), thresholds)
# Out:
# 0.61
# 오차 행렬
# [[57880 11192]
#  [30453 33811]]
# 정확도: 0.6877, 정밀도: 0.7513, 재현율: 0.5261, F1: 0.6189, ROC-AUC: 0.6820
# ################################################################################
# 0.62
# 오차 행렬
# [[58168 10904]
#  [30955 33309]]
# 정확도: 0.6861, 정밀도: 0.7534, 재현율: 0.5183, F1: 0.6141, ROC-AUC: 0.6802
# ################################################################################
# 0.63
# 오차 행렬
# [[58263 10809]
#  [31096 33168]]
# 정확도: 0.6857, 정밀도: 0.7542, 재현율: 0.5161, F1: 0.6129, ROC-AUC: 0.6798
# ################################################################################
# 0.64
# 오차 행렬
# [[58719 10353]
#  [31897 32367]]
# 정확도: 0.6831, 정밀도: 0.7577, 재현율: 0.5037, F1: 0.6051, ROC-AUC: 0.6769
# ################################################################################
# 0.65
# 오차 행렬
# [[59145  9927]
#  [32662 31602]]
# 정확도: 0.6806, 정밀도: 0.7610, 재현율: 0.4918, F1: 0.5974, ROC-AUC: 0.6740
# ...

# %%
proba_class1 = dtc.predict_proba(X_test)[:, 1].reshape(-1, 1)
_, _, thresholds = precision_recall_curve(y_test, proba_class1)
thresholds
# Out:
# array([0.03179147, 0.04714588, 0.04819754, 0.0565915 , 0.06520091,
#        0.06711409, 0.0853717 , 0.08695652, 0.08753709, 0.09265499,
#        0.09311981, 0.10071942, 0.10506398, 0.10666667, 0.11206078,
#        0.11633212, 0.11805556, 0.12121212, 0.12134345, 0.12233348,
#        0.12820513, 0.12840467, 0.13532298, 0.13874254, 0.14210526,
#        0.14647137, 0.14918033, 0.15101237, 0.15380493, 0.15517241,
#        0.16117917, 0.16174121, 0.16583417, 0.16590013, 0.17363344,
#        0.18051385, 0.18181818, 0.19266055, 0.19767442, 0.19984428,
#        0.20612288, 0.20727273, 0.21163636, 0.21201743, 0.21266968,
#        0.21354167, 0.2173913 , 0.22244329, 0.22815534, 0.23076923,
#        0.23962517, 0.24057217, 0.24146982, 0.24316109, 0.24508967,
#        0.24636175, 0.24838013, 0.24880383, 0.24914384, 0.25060827,
#        0.25101764, 0.25281602, 0.2568438 , 0.26247689, 0.27272727,
#        0.27777778, 0.2781457 , 0.28490566, 0.28679775, 0.29036145,
# ...

# %%
get_evaluation_by_thresholds(y_test, proba_class1, thresholds)
# Out:
# 0.03179147205062528
# 오차 행렬
# [[ 1646 67426]
#  [   42 64222]]
# 정확도: 0.4940, 정밀도: 0.4878, 재현율: 0.9993, F1: 0.6556, ROC-AUC: 0.5116
# ################################################################################
# 0.047145877378435515
# 오차 행렬
# [[ 2695 66377]
#  [   85 64179]]
# 정확도: 0.5015, 정밀도: 0.4916, 재현율: 0.9987, F1: 0.6589, ROC-AUC: 0.5188
# ################################################################################
# 0.04819754390598178
# 오차 행렬
# [[ 4487 64585]
#  [  178 64086]]
# 정확도: 0.5143, 정밀도: 0.4981, 재현율: 0.9972, F1: 0.6643, ROC-AUC: 0.5311
# ################################################################################
# 0.05659150043365135
# 오차 행렬
# [[ 5562 63510]
#  [  270 63994]]
# 정확도: 0.5217, 정밀도: 0.5019, 재현율: 0.9958, F1: 0.6674, ROC-AUC: 0.5382
# ################################################################################
# 0.06520090978013647
# 오차 행렬
# [[ 6480 62592]
#  [  336 63928]]
# ...

# %%
_, _, thresholds = roc_curve(y_test, proba_class1)
thresholds
# Out:
# array([2.        , 1.        , 0.92307692, 0.91618103, 0.89449541,
#        0.88216116, 0.87934999, 0.87699019, 0.87548423, 0.85667605,
#        0.83659491, 0.82537479, 0.81920327, 0.81824513, 0.81743666,
#        0.8160723 , 0.80229725, 0.79738562, 0.79385299, 0.79132231,
#        0.78319783, 0.78194444, 0.77831325, 0.77822178, 0.77496038,
#        0.77306273, 0.76417234, 0.76      , 0.74837512, 0.74654908,
#        0.74230522, 0.73601148, 0.73500545, 0.72960619, 0.72794724,
#        0.72505543, 0.71428571, 0.71230159, 0.70748775, 0.70645554,
#        0.70147591, 0.69863014, 0.69671505, 0.69230769, 0.68809202,
#        0.68711036, 0.68543046, 0.68362069, 0.68209877, 0.68028846,
#        0.67869565, 0.67829457, 0.6781728 , 0.67012228, 0.67010309,
#        0.66797933, 0.66762041, 0.66666667, 0.66447368, 0.65526883,
#        0.65367316, 0.65018182, 0.6489842 , 0.64012897, 0.63937138,
#        0.63553826, 0.63404393, 0.62095875, 0.61776794, 0.60993053,
# ...

# %%
# get_evaluation_by_thresholds(y_test, proba_class1, thresholds)

# %% [markdown]
# #### 12. 조정

# %% [markdown]
# - 정밀도를 0.7 이상으로 하기위해 딱 정밀도가 0.7을 넘는 임계치 사용

# %%
# 조정
from sklearn.preprocessing import Binarizer

threshold = 0.5390835579514824

proba = dtc.predict_proba(X_test)
prediction = dtc.predict(X_test)

# %% [markdown]
# #### 13. 테스트

# %%
custom_proba = proba[:, 1].reshape(-1, 1)
binarizer = Binarizer(threshold=threshold).fit(custom_proba)
custom_prediction = binarizer.transform(custom_proba)

get_evaluation(y_test, custom_prediction, visualize=True)
# Out:
# 오차 행렬
# [[51942 17130]
#  [22232 42032]]
# 정확도: 0.7048, 정밀도: 0.7105, 재현율: 0.6541, F1: 0.6811, ROC-AUC: 0.7030
# ################################################################################
