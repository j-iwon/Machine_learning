# %% [markdown]
# ### **Linear Regression Task**
# - 각 광고 종목에 투자했을 때, 수익이 얼만큼 발생하는지 회귀 예측 진행

# %%
import pandas as pd

ad_df = pd.read_csv('./datasets/advertising.csv')

ad_df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
ad_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
columns = ['TV', 'Radio', 'Newspaper', 'Sales']

pre_ad_df = ad_df[columns]
pre_ad_df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
pre_ad_df.hist()
# Out:
# array([[<Axes: title={'center': 'TV'}>,
#         <Axes: title={'center': 'Radio'}>],
#        [<Axes: title={'center': 'Newspaper'}>,
#         <Axes: title={'center': 'Sales'}>]], dtype=object)

# %%
pre_ad_df.corr()['Sales'].sort_values(ascending=False)[1:]
# Out:
# TV           0.782224
# Radio        0.576223
# Newspaper    0.228299
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].scatter(pre_ad_df['TV'], pre_ad_df['Sales'])
axes[1].scatter(pre_ad_df['Radio'], pre_ad_df['Sales'])
axes[2].scatter(pre_ad_df['Newspaper'], pre_ad_df['Sales'])
plt.show()

# %%
pre_ad_df = pre_ad_df[['TV', 'Sales']]
pre_ad_df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
pre_ad_df.hist()
# Out:
# array([[<Axes: title={'center': 'TV'}>,
#         <Axes: title={'center': 'Sales'}>]], dtype=object)

# %%
import numpy as np
pre_ad_df['TV'] = np.log1p(pre_ad_df['TV'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14920\1806646578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_ad_df['TV'] = np.log1p(pre_ad_df['TV'])
# array([[<Axes: title={'center': 'TV'}>,
#         <Axes: title={'center': 'Sales'}>]], dtype=object)
